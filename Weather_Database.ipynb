# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
n = len(cities)
n
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
cities_list = []
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    cities_list.append(city_url)
    print(city_url)

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
         
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_desc})
                          
                        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kadoma
# Processing Record 1 of Set 1 | kadoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=viedma
# Processing Record 2 of Set 1 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=padang
# Processing Record 3 of Set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mabaruma
# Processing Record 4 of Set 1 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=klaksvik
# Processing Record 5 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=poum
# Processing Record 6 of Set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=conceicao+do+araguaia
# Processing Record 7 of Set 1 | conceicao do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=butaritari
# Processing Record 8 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bellavista
# Processing Record 9 of Set 1 | bellavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kaitangata
# Processing Record 10 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=chokurdakh
# Processing Record 11 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=busselton
# Processing Record 12 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mataura
# Processing Record 13 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=aflu
# Processing Record 14 of Set 1 | aflu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tasiilaq
# Processing Record 15 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=manokwari
# Processing Record 16 of Set 1 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=punta+arenas
# Processing Record 17 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=iskateley
# Processing Record 18 of Set 1 | iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=barentsburg
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=upernavik
# Processing Record 20 of Set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=norman+wells
# Processing Record 21 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tuktoyaktuk
# Processing Record 22 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=lalin
# Processing Record 23 of Set 1 | lalin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=codrington
# Processing Record 24 of Set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=castro
# Processing Record 25 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=adrar
# Processing Record 26 of Set 1 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=albany
# Processing Record 27 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=atuona
# Processing Record 28 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=cherskiy
# Processing Record 29 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=capim+grosso
# Processing Record 30 of Set 1 | capim grosso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=taolanaro
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=azua
# Processing Record 32 of Set 1 | azua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=rikitea
# Processing Record 33 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kapaa
# Processing Record 34 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=atar
# Processing Record 35 of Set 1 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=umzimvubu
# Processing Record 36 of Set 1 | umzimvubu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mbandaka
# Processing Record 37 of Set 1 | mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=frontera
# Processing Record 38 of Set 1 | frontera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tunduru
# Processing Record 39 of Set 1 | tunduru
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=olden
# Processing Record 40 of Set 1 | olden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kleinmachnow
# Processing Record 41 of Set 1 | kleinmachnow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ushuaia
# Processing Record 42 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ribeira+grande
# Processing Record 43 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=belushya+guba
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mar+del+plata
# Processing Record 45 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=shubarkuduk
# Processing Record 46 of Set 1 | shubarkuduk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=nemuro
# Processing Record 47 of Set 1 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=constitucion
# Processing Record 48 of Set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kruisfontein
# Processing Record 49 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=palmer
# Processing Record 50 of Set 1 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mastic+beach
# Processing Record 1 of Set 2 | mastic beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=avarua
# Processing Record 2 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=green+valley
# Processing Record 3 of Set 2 | green valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bredasdorp
# Processing Record 4 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=thompson
# Processing Record 5 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kasongo-lunda
# Processing Record 6 of Set 2 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=dhidhdhoo
# Processing Record 7 of Set 2 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=saint-philippe
# Processing Record 8 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=harrismith
# Processing Record 9 of Set 2 | harrismith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bambous+virieux
# Processing Record 10 of Set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=gouyave
# Processing Record 11 of Set 2 | gouyave
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=anshun
# Processing Record 12 of Set 2 | anshun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=pevek
# Processing Record 13 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=puerto+ayora
# Processing Record 14 of Set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=magomeni
# Processing Record 15 of Set 2 | magomeni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=dikson
# Processing Record 16 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hinton
# Processing Record 17 of Set 2 | hinton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=quarai
# Processing Record 18 of Set 2 | quarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bouar
# Processing Record 19 of Set 2 | bouar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mayo
# Processing Record 20 of Set 2 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=cape+town
# Processing Record 21 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=laguna
# Processing Record 22 of Set 2 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tahoua
# Processing Record 23 of Set 2 | tahoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hermanus
# Processing Record 24 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=salym
# Processing Record 25 of Set 2 | salym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=gushikawa
# Processing Record 26 of Set 2 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=oussouye
# Processing Record 27 of Set 2 | oussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hervey+bay
# Processing Record 28 of Set 2 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=altonia
# Processing Record 29 of Set 2 | altonia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=east+london
# Processing Record 30 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ravar
# Processing Record 31 of Set 2 | ravar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ugoofaaru
# Processing Record 32 of Set 2 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=safford
# Processing Record 33 of Set 2 | safford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=shelburne
# Processing Record 34 of Set 2 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=karratha
# Processing Record 35 of Set 2 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mehamn
# Processing Record 36 of Set 2 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=roncesvalles
# Processing Record 37 of Set 2 | roncesvalles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=repnoye
# Processing Record 38 of Set 2 | repnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=boguchany
# Processing Record 39 of Set 2 | boguchany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=la+rioja
# Processing Record 40 of Set 2 | la rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=saint+anthony
# Processing Record 41 of Set 2 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bethel
# Processing Record 42 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=taoudenni
# Processing Record 43 of Set 2 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=thio
# Processing Record 44 of Set 2 | thio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=san+cristobal
# Processing Record 45 of Set 2 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kutum
# Processing Record 46 of Set 2 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=idrinskoye
# Processing Record 47 of Set 2 | idrinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=esperance
# Processing Record 48 of Set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=waingapu
# Processing Record 49 of Set 2 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=talcahuano
# Processing Record 50 of Set 2 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=dunedin
# Processing Record 1 of Set 3 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hofn
# Processing Record 2 of Set 3 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ebebiyin
# Processing Record 3 of Set 3 | ebebiyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=illoqqortoormiut
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=clute
# Processing Record 5 of Set 3 | clute
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=zhuhai
# Processing Record 6 of Set 3 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sao+filipe
# Processing Record 7 of Set 3 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=nikolskoye
# Processing Record 8 of Set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bluff
# Processing Record 9 of Set 3 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tucurui
# Processing Record 10 of Set 3 | tucurui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ludvika
# Processing Record 11 of Set 3 | ludvika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=egvekinot
# Processing Record 12 of Set 3 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mazatlan
# Processing Record 13 of Set 3 | mazatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tuzha
# Processing Record 14 of Set 3 | tuzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=provideniya
# Processing Record 15 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=jaranwala
# Processing Record 16 of Set 3 | jaranwala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kavieng
# Processing Record 17 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=alice+springs
# Processing Record 18 of Set 3 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=havre-saint-pierre
# Processing Record 19 of Set 3 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=maningrida
# Processing Record 20 of Set 3 | maningrida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hilo
# Processing Record 21 of Set 3 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=port+elizabeth
# Processing Record 22 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=barrow
# Processing Record 23 of Set 3 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=coihaique
# Processing Record 24 of Set 3 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ranau
# Processing Record 25 of Set 3 | ranau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=the+valley
# Processing Record 26 of Set 3 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=jamestown
# Processing Record 27 of Set 3 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=isangel
# Processing Record 28 of Set 3 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kloulklubed
# Processing Record 29 of Set 3 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=baykit
# Processing Record 30 of Set 3 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=longyearbyen
# Processing Record 31 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=berdigestyakh
# Processing Record 32 of Set 3 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=yellowknife
# Processing Record 33 of Set 3 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=qaanaaq
# Processing Record 34 of Set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sentyabrskiy
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=krasnorechenskiy
# Processing Record 36 of Set 3 | krasnorechenskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=humberto+de+campos
# Processing Record 37 of Set 3 | humberto de campos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=nelson+bay
# Processing Record 38 of Set 3 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=maragogi
# Processing Record 39 of Set 3 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mys+shmidta
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=adamovka
# Processing Record 41 of Set 3 | adamovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=zambezi
# Processing Record 42 of Set 3 | zambezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=lebu
# Processing Record 43 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bubaque
# Processing Record 44 of Set 3 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=same
# Processing Record 45 of Set 3 | same
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mangrol
# Processing Record 46 of Set 3 | mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ternate
# Processing Record 47 of Set 3 | ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=carnarvon
# Processing Record 48 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=chuy
# Processing Record 49 of Set 3 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=narsaq
# Processing Record 50 of Set 3 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=khatanga
# Processing Record 1 of Set 4 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=nome
# Processing Record 2 of Set 4 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=fare
# Processing Record 3 of Set 4 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=clyde+river
# Processing Record 4 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=cabo+san+lucas
# Processing Record 5 of Set 4 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=la+ronge
# Processing Record 6 of Set 4 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=faanui
# Processing Record 7 of Set 4 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=vaini
# Processing Record 8 of Set 4 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mao
# Processing Record 9 of Set 4 | mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=harboore
# Processing Record 10 of Set 4 | harboore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ancud
# Processing Record 11 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kodiak
# Processing Record 12 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=nouadhibou
# Processing Record 13 of Set 4 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sagauli
# Processing Record 14 of Set 4 | sagauli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=oksfjord
# Processing Record 15 of Set 4 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=minab
# Processing Record 16 of Set 4 | minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=salalah
# Processing Record 17 of Set 4 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=amderma
# Processing Record 18 of Set 4 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=javanrud
# Processing Record 19 of Set 4 | javanrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=farafangana
# Processing Record 20 of Set 4 | farafangana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=port+alfred
# Processing Record 21 of Set 4 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=santa+maria
# Processing Record 22 of Set 4 | santa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=millville
# Processing Record 23 of Set 4 | millville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=new+norfolk
# Processing Record 24 of Set 4 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=naze
# Processing Record 25 of Set 4 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sur
# Processing Record 26 of Set 4 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=vila+velha
# Processing Record 27 of Set 4 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=isabela
# Processing Record 28 of Set 4 | isabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=aklavik
# Processing Record 29 of Set 4 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=jos
# Processing Record 30 of Set 4 | jos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=iqaluit
# Processing Record 31 of Set 4 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=luena
# Processing Record 32 of Set 4 | luena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=shache
# Processing Record 33 of Set 4 | shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=porto+novo
# Processing Record 34 of Set 4 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kastamonu
# Processing Record 35 of Set 4 | kastamonu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=isla+mujeres
# Processing Record 36 of Set 4 | isla mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=puerto+escondido
# Processing Record 37 of Set 4 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=arraial+do+cabo
# Processing Record 38 of Set 4 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=alistrati
# Processing Record 39 of Set 4 | alistrati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=saskylakh
# Processing Record 40 of Set 4 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=itarema
# Processing Record 41 of Set 4 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=alofi
# Processing Record 42 of Set 4 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=xichang
# Processing Record 43 of Set 4 | xichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=samusu
# Processing Record 44 of Set 4 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=diebougou
# Processing Record 45 of Set 4 | diebougou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=georgetown
# Processing Record 46 of Set 4 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sjovegan
# Processing Record 47 of Set 4 | sjovegan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=dingzhou
# Processing Record 48 of Set 4 | dingzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=grand+river+south+east
# Processing Record 49 of Set 4 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=nara
# Processing Record 50 of Set 4 | nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=lavrentiya
# Processing Record 1 of Set 5 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bargal
# Processing Record 2 of Set 5 | bargal
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=namibe
# Processing Record 3 of Set 5 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sola
# Processing Record 4 of Set 5 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=russell
# Processing Record 5 of Set 5 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=plettenberg+bay
# Processing Record 6 of Set 5 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sakaiminato
# Processing Record 7 of Set 5 | sakaiminato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tokzar
# Processing Record 8 of Set 5 | tokzar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=fortuna
# Processing Record 9 of Set 5 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=pemangkat
# Processing Record 10 of Set 5 | pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=qaqortoq
# Processing Record 11 of Set 5 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=paralimni
# Processing Record 12 of Set 5 | paralimni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=maputo
# Processing Record 13 of Set 5 | maputo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=san+patricio
# Processing Record 14 of Set 5 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=thinadhoo
# Processing Record 15 of Set 5 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=san+joaquin
# Processing Record 16 of Set 5 | san joaquin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=camacha
# Processing Record 17 of Set 5 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=miguel+hidalgo
# Processing Record 18 of Set 5 | miguel hidalgo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bereda
# Processing Record 19 of Set 5 | bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=copiapo
# Processing Record 20 of Set 5 | copiapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=samsun
# Processing Record 21 of Set 5 | samsun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=touros
# Processing Record 22 of Set 5 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=shimoda
# Processing Record 23 of Set 5 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=fuerte+olimpo
# Processing Record 24 of Set 5 | fuerte olimpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=virginia+beach
# Processing Record 25 of Set 5 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=saldanha
# Processing Record 26 of Set 5 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kulhudhuffushi
# Processing Record 27 of Set 5 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=haibowan
# Processing Record 28 of Set 5 | haibowan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=labutta
# Processing Record 29 of Set 5 | labutta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tocopilla
# Processing Record 30 of Set 5 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=marcona
# Processing Record 31 of Set 5 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=namatanai
# Processing Record 32 of Set 5 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=turukhansk
# Processing Record 33 of Set 5 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kiunga
# Processing Record 34 of Set 5 | kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tefe
# Processing Record 35 of Set 5 | tefe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=pisco
# Processing Record 36 of Set 5 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=longlac
# Processing Record 37 of Set 5 | longlac
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=chicama
# Processing Record 38 of Set 5 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=denpasar
# Processing Record 39 of Set 5 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=miyako
# Processing Record 40 of Set 5 | miyako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=nizhneyansk
# Processing Record 41 of Set 5 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sitka
# Processing Record 42 of Set 5 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bani
# Processing Record 43 of Set 5 | bani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=saint+george
# Processing Record 44 of Set 5 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=micheweni
# Processing Record 45 of Set 5 | micheweni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=raudeberg
# Processing Record 46 of Set 5 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hobart
# Processing Record 47 of Set 5 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=namie
# Processing Record 48 of Set 5 | namie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=erzin
# Processing Record 49 of Set 5 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=marawi
# Processing Record 50 of Set 5 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=polunochnoye
# Processing Record 1 of Set 6 | polunochnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mandalay
# Processing Record 2 of Set 6 | mandalay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=belgrade
# Processing Record 3 of Set 6 | belgrade
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=praya
# Processing Record 4 of Set 6 | praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=yurgamysh
# Processing Record 5 of Set 6 | yurgamysh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=oromocto
# Processing Record 6 of Set 6 | oromocto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=saint-augustin
# Processing Record 7 of Set 6 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=havelock
# Processing Record 8 of Set 6 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=chumphon
# Processing Record 9 of Set 6 | chumphon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tura
# Processing Record 10 of Set 6 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hasaki
# Processing Record 11 of Set 6 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=savannah+bight
# Processing Record 12 of Set 6 | savannah bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=port+hardy
# Processing Record 13 of Set 6 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tiksi
# Processing Record 14 of Set 6 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hobyo
# Processing Record 15 of Set 6 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=saraland
# Processing Record 16 of Set 6 | saraland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=gra+liyia
# Processing Record 17 of Set 6 | gra liyia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=pitimbu
# Processing Record 18 of Set 6 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=meyungs
# Processing Record 19 of Set 6 | meyungs
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=aranos
# Processing Record 20 of Set 6 | aranos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=fasa
# Processing Record 21 of Set 6 | fasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hargeysa
# Processing Record 22 of Set 6 | hargeysa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=leningradskiy
# Processing Record 23 of Set 6 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=luderitz
# Processing Record 24 of Set 6 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=am+timan
# Processing Record 25 of Set 6 | am timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=palabuhanratu
# Processing Record 26 of Set 6 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=dossor
# Processing Record 27 of Set 6 | dossor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=mount+isa
# Processing Record 28 of Set 6 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=we
# Processing Record 29 of Set 6 | we
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ola
# Processing Record 30 of Set 6 | ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=coquimbo
# Processing Record 31 of Set 6 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bathsheba
# Processing Record 32 of Set 6 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=vysokogornyy
# Processing Record 33 of Set 6 | vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=swan+river
# Processing Record 34 of Set 6 | swan river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ostrovnoy
# Processing Record 35 of Set 6 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=magway
# Processing Record 36 of Set 6 | magway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=christchurch
# Processing Record 37 of Set 6 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=puerto+narino
# Processing Record 38 of Set 6 | puerto narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=severo-kurilsk
# Processing Record 39 of Set 6 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=manturovo
# Processing Record 40 of Set 6 | manturovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bengkulu
# Processing Record 41 of Set 6 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=dejen
# Processing Record 42 of Set 6 | dejen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=vaitupu
# Processing Record 43 of Set 6 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=dalbandin
# Processing Record 44 of Set 6 | dalbandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=saquarema
# Processing Record 45 of Set 6 | saquarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=jiblah
# Processing Record 46 of Set 6 | jiblah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=aberdeen
# Processing Record 47 of Set 6 | aberdeen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=grindavik
# Processing Record 48 of Set 6 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=buala
# Processing Record 49 of Set 6 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hof
# Processing Record 50 of Set 6 | hof
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ximei
# Processing Record 1 of Set 7 | ximei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=slonim
# Processing Record 2 of Set 7 | slonim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=doha
# Processing Record 3 of Set 7 | doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=komsomolskiy
# Processing Record 4 of Set 7 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bilma
# Processing Record 5 of Set 7 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ahipara
# Processing Record 6 of Set 7 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=svetlyy+yar
# Processing Record 7 of Set 7 | svetlyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sumbe
# Processing Record 8 of Set 7 | sumbe
# ...
# Processing Record 5 of Set 14 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=abu+zabad
# Processing Record 6 of Set 14 | abu zabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=challapata
# Processing Record 7 of Set 14 | challapata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sorland
# Processing Record 8 of Set 14 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tommot
# Processing Record 9 of Set 14 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bay+roberts
# Processing Record 10 of Set 14 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sibenik
# Processing Record 11 of Set 14 | sibenik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=rawson
# Processing Record 12 of Set 14 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=khor
# Processing Record 13 of Set 14 | khor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=garissa
# Processing Record 14 of Set 14 | garissa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=westport
# Processing Record 15 of Set 14 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=harper
# Processing Record 16 of Set 14 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=sackville
# Processing Record 17 of Set 14 | sackville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=aksay
# Processing Record 18 of Set 14 | aksay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=papar
# Processing Record 19 of Set 14 | papar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=nanzhou
# Processing Record 20 of Set 14 | nanzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=necochea
# Processing Record 21 of Set 14 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=williams+lake
# Processing Record 22 of Set 14 | williams lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=seoul
# Processing Record 23 of Set 14 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=leh
# Processing Record 24 of Set 14 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=haines+junction
# Processing Record 25 of Set 14 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=waddan
# Processing Record 26 of Set 14 | waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=rockwall
# Processing Record 27 of Set 14 | rockwall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kailaras
# Processing Record 28 of Set 14 | kailaras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=waipawa
# Processing Record 29 of Set 14 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=santa+rita
# Processing Record 30 of Set 14 | santa rita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=nueva+italia+de+ruiz
# Processing Record 31 of Set 14 | nueva italia de ruiz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tumannyy
# Processing Record 32 of Set 14 | tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=reinosa
# Processing Record 33 of Set 14 | reinosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=setubal
# Processing Record 34 of Set 14 | setubal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=terrace+bay
# Processing Record 35 of Set 14 | terrace bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=waiouru
# Processing Record 36 of Set 14 | waiouru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=buga
# Processing Record 37 of Set 14 | buga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kosh-agach
# Processing Record 38 of Set 14 | kosh-agach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=qostanay
# Processing Record 39 of Set 14 | qostanay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kilindoni
# Processing Record 40 of Set 14 | kilindoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=dobsina
# Processing Record 41 of Set 14 | dobsina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=toyooka
# Processing Record 42 of Set 14 | toyooka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=vardo
# Processing Record 43 of Set 14 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=huarmey
# Processing Record 44 of Set 14 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=magbay
# Processing Record 45 of Set 14 | magbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bull+savanna
# Processing Record 46 of Set 14 | bull savanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=birao
# Processing Record 47 of Set 14 | birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=zyryanka
# Processing Record 48 of Set 14 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=monduli
# Processing Record 49 of Set 14 | monduli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=razole
# Processing Record 50 of Set 14 | razole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tanout
# Processing Record 1 of Set 15 | tanout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=itoman
# Processing Record 2 of Set 15 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=vestby
# Processing Record 3 of Set 15 | vestby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=karamay
# Processing Record 4 of Set 15 | karamay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kalmunai
# Processing Record 5 of Set 15 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=cockburn+harbour
# Processing Record 6 of Set 15 | cockburn harbour
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hudiksvall
# Processing Record 7 of Set 15 | hudiksvall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tomatlan
# Processing Record 8 of Set 15 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kalanchak
# Processing Record 9 of Set 15 | kalanchak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hualmay
# Processing Record 10 of Set 15 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=okhotsk
# Processing Record 11 of Set 15 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=timberlake
# Processing Record 12 of Set 15 | timberlake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=rassvet
# Processing Record 13 of Set 15 | rassvet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=castro+marim
# Processing Record 14 of Set 15 | castro marim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=alugan
# Processing Record 15 of Set 15 | alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=pula
# Processing Record 16 of Set 15 | pula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=rock+springs
# Processing Record 17 of Set 15 | rock springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=westpunt
# Processing Record 18 of Set 15 | westpunt
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=zlitan
# Processing Record 19 of Set 15 | zlitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=yerbogachen
# Processing Record 20 of Set 15 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=teguise
# Processing Record 21 of Set 15 | teguise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kozlovka
# Processing Record 22 of Set 15 | kozlovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=coxim
# Processing Record 23 of Set 15 | coxim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=solovetskiy
# Processing Record 24 of Set 15 | solovetskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kondopoga
# Processing Record 25 of Set 15 | kondopoga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=batagay-alyta
# Processing Record 26 of Set 15 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=galesong
# Processing Record 27 of Set 15 | galesong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=meulaboh
# Processing Record 28 of Set 15 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=malwan
# Processing Record 29 of Set 15 | malwan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=wajid
# Processing Record 30 of Set 15 | wajid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=eureka
# Processing Record 31 of Set 15 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=praia+da+vitoria
# Processing Record 32 of Set 15 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=santa+paula
# Processing Record 33 of Set 15 | santa paula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=hamilton
# Processing Record 34 of Set 15 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bandarbeyla
# Processing Record 35 of Set 15 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=oum+hadjer
# Processing Record 36 of Set 15 | oum hadjer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=puerto+lopez
# Processing Record 37 of Set 15 | puerto lopez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=tonstad
# Processing Record 38 of Set 15 | tonstad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=broken+hill
# Processing Record 39 of Set 15 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=lagoa
# Processing Record 40 of Set 15 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=burlington
# Processing Record 41 of Set 15 | burlington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=quirinopolis
# Processing Record 42 of Set 15 | quirinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=thunder+bay
# Processing Record 43 of Set 15 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=boda
# Processing Record 44 of Set 15 | boda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=piste
# Processing Record 45 of Set 15 | piste
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=san+andres
# Processing Record 46 of Set 15 | san andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=key+west
# Processing Record 47 of Set 15 | key west
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=severo-yeniseyskiy
# Processing Record 48 of Set 15 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ballina
# Processing Record 49 of Set 15 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=bayir
# Processing Record 50 of Set 15 | bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=salta
# Processing Record 1 of Set 16 | salta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=santa+rosa
# Processing Record 2 of Set 16 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=kidal
# Processing Record 3 of Set 16 | kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=pafos
# Processing Record 4 of Set 16 | pafos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=ingham
# Processing Record 5 of Set 16 | ingham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1370ee5b09ccb9b8c2528c77c7f4440&q=placido+de+castro
# Processing Record 6 of Set 16 | placido de castro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Kadoma  34.7333  135.5833     52.00        71          75
# 1               Viedma -40.8135  -62.9967     73.90        54         100
# 2               Padang  -0.9492  100.3543     73.40       100          20
# 3             Mabaruma   8.2000  -59.7833     74.66        94         100
# 4             Klaksvik  62.2266   -6.5890     24.80        93          75
# ..                 ...      ...       ...       ...       ...         ...
# 698         Santa Rosa  14.3122  121.1114     82.99        74          75
# 699              Kidal  18.4411    1.4078     81.95         7          31
# 700              Pafos  34.7667   32.4167     55.00        82           0
# 701             Ingham  42.6000  -84.3833     61.00        67           1
# 702  Placido De Castro -10.3353  -67.1856     71.60        98         100
#
#      Wind Speed Country Current Description
# 0          4.61      JP       broken clouds
# 1         13.60      AR     overcast clouds
# 2          3.44      ID          few clouds
# 3          3.47      GY     overcast clouds
# 4         39.12      FO          light snow
# ..          ...     ...                 ...
# 698        3.44      PH       broken clouds
# 699        4.03      ML    scattered clouds
# 700        3.44      CY           clear sky
# 701        5.75      US           clear sky
# 702        0.85      BR     overcast clouds
#
# [703 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
